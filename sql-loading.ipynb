# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import numpy as np
import pandas as pd

# %%
dataset=pd.read_csv('/kaggle/input/craigslist-vehicles/craigslist_vehicles.csv')

# %%
dataset.head()
# Out:
#    Unnamed: 0          id                                                url  \
# 0      362773  7307679724  https://abilene.craigslist.org/ctd/d/abilene-2...
# 1      362712  7311833696  https://abilene.craigslist.org/ctd/d/abilene-2...
# 2      362722  7311441996  https://abilene.craigslist.org/ctd/d/abilene-2...
# 3      362771  7307680715  https://abilene.craigslist.org/ctd/d/abilene-2...
# 4      362710  7311834578  https://abilene.craigslist.org/ctd/d/abilene-2...
#
#     region                      region_url  price    year manufacturer  \
# 0  abilene  https://abilene.craigslist.org   4500  2002.0          bmw
# 1  abilene  https://abilene.craigslist.org   4500  2002.0          bmw
# 2  abilene  https://abilene.craigslist.org   4900  2006.0       toyota
# 3  abilene  https://abilene.craigslist.org   6500  2008.0         ford
# 4  abilene  https://abilene.craigslist.org   6500  2008.0         ford
#
#         model  condition  ...   type paint_color  \
# 0          x5        NaN  ...    NaN         NaN
# 1          x5        NaN  ...    NaN         NaN
# 2       camry  excellent  ...  sedan      silver
# 3  expedition        NaN  ...    NaN         NaN
# 4  expedition        NaN  ...    NaN         NaN
#
#                                            image_url  \
# 0  https://images.craigslist.org/00m0m_iba78h8ty9...
# 1  https://images.craigslist.org/00m0m_iba78h8ty9...
# 2  https://images.craigslist.org/00808_5FkOw2aGjA...
# 3  https://images.craigslist.org/00M0M_i9CoFvVq8o...
# 4  https://images.craigslist.org/00M0M_i9CoFvVq8o...
#
#                                          description county state        lat  \
# 0  $4,500 Cash  2002 BMW X5  8 cylinder 4.4L moto...    NaN    tx  32.401556
# 1  $4,500 Cash  2002 BMW X5  8 cylinder 4.4L moto...    NaN    tx  32.401556
# 2  2006 TOYOTA CAMRY LE Sedan   Ready To Upgrade ...    NaN    tx  32.453848
# 3  $6500.00 2008 Ford Expedition  8 cylinder 5.4L...    NaN    tx  32.401556
# 4  $6500.00 2008 Ford Expedition  8 cylinder 5.4L...    NaN    tx  32.401556
#
#         long               posting_date               removal_date
# 0 -99.884713  2021-04-16 00:00:00+00:00  2021-05-02 00:00:00+00:00
# 1 -99.884713  2021-04-24 00:00:00+00:00  2021-04-28 00:00:00+00:00
# 2 -99.787900  2021-04-23 00:00:00+00:00  2021-05-25 00:00:00+00:00
# 3 -99.884713  2021-04-16 00:00:00+00:00  2021-04-26 00:00:00+00:00
# 4 -99.884713  2021-04-24 00:00:00+00:00  2021-05-12 00:00:00+00:00
#
# [5 rows x 28 columns]

# %%
dataset.shape
# Out:
# (426880, 28)

# %%
#columns to drop
columns_drop=['Unnamed:0','url','region_url','VIN','image_url','removal_date','lat','long']
#dropping only the columns existing in the dataframe
columns_existing=[i for i in columns_drop if i in dataset.columns]
#dropping the columns
dataset=dataset.drop(columns=columns_existing)


dataset.columns
# Out:
# Index(['Unnamed: 0', 'id', 'region', 'price', 'year', 'manufacturer', 'model',
#        'condition', 'cylinders', 'fuel', 'odometer', 'title_status',
#        'transmission', 'drive', 'size', 'type', 'paint_color', 'description',
#        'county', 'state', 'posting_date'],
#       dtype='object')

# %%
#handlinng missing values
def missing_values_handling(dataset):
    # Handling numerical data
    numeric_data = ['year', 'odometer']
    dataset[numeric_data] = dataset[numeric_data].fillna(dataset[numeric_data].median())

    # Handling categorical data
    categorical_data = ['manufacturer', 'model', 'condition', 'cylinders', 'fuel', 'title_status', 'transmission', 'drive', 'size', 'type', 'paint_color', 'description', 'county']
    for column in categorical_data:
        dataset[column] = dataset[column].fillna('Unknown')  # Replace with 'Unknown' or another appropriate value

    return dataset

# Example usage
dataset = pd.DataFrame(dataset)  # Replace with your dataset
dataset = missing_values_handling(dataset)

# %%
dataset.isnull().sum()
# Out:
# Unnamed: 0       0
# id               0
# region           0
# price            0
# year             0
# manufacturer     0
# model            0
# condition        0
# cylinders        0
# fuel             0
# odometer         0
# title_status     0
# transmission     0
# drive            0
# size             0
# type             0
# paint_color      0
# description      0
# county           0
# state            0
# posting_date    68
# dtype: int64

# %%
dataset['posting_date']=pd.to_datetime(dataset['posting_date'])

# %%
dataset.dtypes
# Out:
# Unnamed: 0                    int64
# id                            int64
# region                       object
# price                         int64
# year                        float64
# manufacturer                 object
# model                        object
# condition                    object
# cylinders                    object
# fuel                         object
# odometer                    float64
# title_status                 object
# transmission                 object
# drive                        object
# size                         object
# type                         object
# paint_color                  object
# description                  object
# county                       object
# state                        object
# posting_date    datetime64[ns, UTC]
# dtype: object

# %%
dataset=dataset.astype({'price':float,'odometer':int,'year':int})

# %%
dataset.dtypes
# Out:
# Unnamed: 0                    int64
# id                            int64
# region                       object
# price                       float64
# year                          int64
# manufacturer                 object
# model                        object
# condition                    object
# cylinders                    object
# fuel                         object
# odometer                      int64
# title_status                 object
# transmission                 object
# drive                        object
# size                         object
# type                         object
# paint_color                  object
# description                  object
# county                       object
# state                        object
# posting_date    datetime64[ns, UTC]
# dtype: object

# %% [markdown]
# ### DATAFRAME EXPORT

# %%
col=[]
for i in range(len(dataset)):
    x=tuple(dataset.iloc[i])
    col.append(x)
    
col
# Out:
# [(362773,
#   7307679724,
#   'abilene',
#   4500.0,
#   2002,
#   'bmw',
#   'x5',
#   'Unknown',
#   'Unknown',
#   'gas',
#   184000,
#   'clean',
#   'automatic',
#   'Unknown',
#   'Unknown',
#   'Unknown',
#   'Unknown',
#   '$4,500 Cash  2002 BMW X5  8 cylinder 4.4L motor  Automatic transmission  184k miles Leather seats  Cold Ac and great heater This car runs great, has a new water pump! Leather seat are in good condition. Has some small issues with the interior.￼￼Does have some small blemishes. This is a great car, come by and take it for a test drive! Let’s make a deal!  Call or text BMW  512-653-0636 Stop by  LNC Auto Sales  1842 N First st Abilene Tx 79603',
#   'Unknown',
#   'tx',
#   Timestamp('2021-04-16 00:00:00+0000', tz='UTC')),
#  (362712,
#   7311833696,
#   'abilene',
#   4500.0,
#   2002,
#   'bmw',
#   'x5',
#   'Unknown',
#   'Unknown',
#   'gas',
#   184000,
#   'clean',
#   'automatic',
#   'Unknown',
#   'Unknown',
#   'Unknown',
#   'Unknown',
#   '$4,500 Cash  2002 BMW X5  8 cylinder 4.4L motor  Automatic transmission  184k miles Leather seats  Cold Ac and great heater This car runs great, has a new water pump! Leather seat are in good condition. Has some small issues with the interior.￼￼Does have some small blemishes. This is a great car, come by and take it for a test drive! Let’s make a deal!  Call or text BMW  512-653-0636 Stop by  LNC Auto Sales  1842 N First st Abilene Tx 79603',
#   'Unknown',
#   'tx',
#   Timestamp('2021-04-24 00:00:00+0000', tz='UTC')),
#  (362722,
#   7311441996,
#   'abilene',
#   4900.0,
#   2006,
#   'toyota',
#   'camry',
#   'excellent',
#   '4 cylinders',
#   'gas',
#   184930,
#   'clean',
#   'automatic',
#   'fwd',
#   'Unknown',
#   'sedan',
#   'silver',
#   "2006 TOYOTA CAMRY LE Sedan   Ready To Upgrade Your Ride Today? We Make It Fast & Easy!Call (or text) ☏ (325) 725−8154  Richard Roberts Motors 134 N. Clack Street, Abilene, TX 79603Copy & Paste the URL belowto view more information!http://richardrobertsmotors.com   \t\t\tYear : 2006\t\t\t\tMake : TOYOTA\t\t\t\tModel : CAMRY\t\t\t\tTrim : LE\t\t\t\t   Mileage : 184,930 miles\t\t\t\tTransmission : Automatic\t\t\t\tExterior Color : SILVER\t\t\t\tInterior Color : GRAY\t\t\t\tSeries : LE Sedan\t\t\t\tDrivetrain : FWD\t\t\t\tCondition : Excellent\t\t\t\t\tStock ID : 1075\t\t\t\tEngine : 2.4L\t   > > > $4,900 < < <   Description of this TOYOTA CAMRY LE  Nice Toyota Camry. Power windows, power locks, tilt, cruise, and power seat. Cash, personal check, credit card or outside financing only. Thank you for you interest.     🚘 Richard Roberts Motors 🚘 ✅ Huge Selection Of Quality Pre-Owned Cars ✅ Leave The Lot With Confidence ✅ Trade-In Your Car Today For A Great Discount  ✅ We Buy Cars Cash  📍 Stop By Today And See Why Our Dealership Is Always The People's Choice💥 Check Out More Of Our Great Cars On Craigslist Just Copy And Paste This Link Into Your Browser 💥 https://abilene.craigslist.org/search/ctd?query=richardrobertsmotors.com     Call (or text)  (325) 725−8154 for quick answers to your questions about this TOYOTA CAMRY LE.   ***** TOYOTA CAMRY LE Sedan *****  2007, 2008, 2009, 2006, 2005, 2004, 2003, TOYOTA CAMRY, 4Runner, Avalon, Camry, Camry Solara, Celica, Corolla, ECHO, Highlander, Land Cruiser, MR2, Matrix, Prius, RAV4, Sequoia, Sienna, Tundra, Tacoma, RAV4 EV, Highlander Hybrid, Camry Hybrid, FJ Cruiser, Yaris, Venza   Disclaimer : * Please Note All Inventory And Inventory Pricing Is Subject To Change Please See Dealer For Further Details *     Ready To Upgrade Your Ride Today? We Make It Fast & Easy!Call (or text) ☏ (325) 725−8154  Richard Roberts Motors 134 N. Clack Street, Abilene, TX 79603Copy & Paste the URL belowto view more information!http://richardrobertsmotors.com    2006 06 *TOYOTA* *CAMRY* *Cheap LE* \t\t*Like New 2006 LE Sedan* *2.4L* \t\t*Must See 2006 TOYOTA CAMRY LE Gasoline - \t\t2006 TOYOTA CAMRY  camry CAMRY LE Gasoline Sedan Cheap -  \t\t2006 TOYOTA CAMRY (LE) Carfax Gasoline 2.4L -  \t\t2006 TOYOTA CAMRY LE Sedan 2.4L Gasoline  -  \t\tTOYOTA CAMRY LE Sedan   \t\t*SCHEDULE YOUR TEST DRIVE 2006 TOYOTA CAMRY  2.4L LE Gasoline Sedan*   \t\t*TOYOTA* *CAMRY* 2006 TOYOTA CAMRY LE Gasoline Sedan   \t\t*2006 TOYOTA CAMRY LE  \t\t*Richard Roberts Motors* *Call (or text) us today at (325) 725−8154.* \t\t2007 TOYOTA CAMRY LE 2.4L - \t\tHave you seen this 2008 TOYOTA CAMRY LE Sedan ?  \t\tMust See 2009 TOYOTA CAMRY  LE Gasoline Sedan  \t\t*For Sale CAMRY* *CAMRY* *Carfax LE Gasoline Sedan  \t\tCome test drive this amazing *TOYOTA* *CAMRY* *(LE)* *Gasoline* Sedan LE Sedan Gasoline Sedan Gasoline* \t\t*(TOYOTA)* *(CAMRY)* *LE* *2.4L* *(GASOLINE)* *Bad Credit* \t\t*Gasoline* *Sedan*  *Super Vehicle Gasoline Call (or text) this number (325) 725−8154* *2.4L* *Richard Roberts Motors* * Good Credit* \t\t2006 2005 2004 2003  \t\t*This vehicle is a used TOYOTA CAMRY* *No Credit* \t\t*It is like New LE* *2.4L Gasoline*  \t\t*Gasoline* 2002 2001 2000 1999 1998 1997",
#   'Unknown',
#   'tx',
#   Timestamp('2021-04-23 00:00:00+0000', tz='UTC')),
#  (362771,
#   7307680715,
#   'abilene',
#   6500.0,
#   2008,
#   'ford',
#   'expedition',
#   'Unknown',
#   'Unknown',
#   'gas',
#   206000,
#   'clean',
#   'automatic',
#   'Unknown',
#   'Unknown',
#   'Unknown',
#   'Unknown',
#   '$6500.00 2008 Ford Expedition  8 cylinder 5.4L  206,183-k miles  Automatic transmission  Leather seats Cold ac/heat This is a great running vehicle, very smooth ride to it. 3rd row seats great family car, also includes DVD player. Leather seats do have some rips and tears as shown in pictures, can be covered with seat covers. Bring your mechanic by and come test drive this vehicle! Call or text  512-653-063six Stop by LNC Auto Sales  1842 north 1st Abilene Tx 79603',
#   'Unknown',
#   'tx',
#   Timestamp('2021-04-16 00:00:00+0000', tz='UTC')),
#  (362710,
#   7311834578,
#   'abilene',
#   6500.0,
#   2008,
#   'ford',
#   'expedition',
#   'Unknown',
#   'Unknown',
#   'gas',
#   206000,
#   'clean',
#   'automatic',
#   'Unknown',
#   'Unknown',
#   'Unknown',
#   'Unknown',
#   '$6500.00 2008 Ford Expedition  8 cylinder 5.4L  206,183-k miles  Automatic transmission  Leather seats Cold ac/heat This is a great running vehicle, very smooth ride to it. 3rd row seats great family car, also includes DVD player. Leather seats do have some rips and tears as shown in pictures, can be covered with seat covers. Bring your mechanic by and come test drive this vehicle! Call or text  512-653-063six Stop by LNC Auto Sales  1842 north 1st Abilene Tx 79603',
#   'Unknown',
#   'tx',
#   Timestamp('2021-04-24 00:00:00+0000', tz='UTC')),
#  (362772,
#   7307680254,
#   'abilene',
#   6500.0,
#   2008,
#   'honda',
#   'odyssey',
#   'Unknown',
#   'Unknown',
#   'gas',
#   141000,
#   'clean',
#   'automatic',
#   'Unknown',
#   'Unknown',
#   'Unknown',
#   'Unknown',
#   '$6500.00 Cash  2008 Honda Odyssey  6 cylinder 3.5L  141,465-k miles Automatic transmission  Cloth seats  Cold ac/heat This van runs and drives great. Has a lot of room in the back, does have 3rd row. This van is very clean and has plenty of cup holders. Bring your mechanic by and take it for a test drive.  Call or text  512-653-063six Stop by LNC Auto Sales',
#   'Unknown',
#   'tx',
#   Timestamp('2021-04-16 00:00:00+0000', tz='UTC')),
#  (362711,
#   7311834077,
#   'abilene',
#   6500.0,
#   2008,
#   'honda',
#   'odyssey',
#   'Unknown',
#   'Unknown',
#   'gas',
#   141000,
#   'clean',
#   'automatic',
#   'Unknown',
#   'Unknown',
#   'Unknown',
#   'Unknown',
#   '$6500.00 Cash  2008 Honda Odyssey  6 cylinder 3.5L  141,465-k miles Automatic transmission  Cloth seats  Cold ac/heat This van runs and drives great. Has a lot of room in the back, does have 3rd row. This van is very clean and has plenty of cup holders. Bring your mechanic by and take it for a test drive.  Call or text  512-653-063six Stop by LNC Auto Sales',
#   'Unknown',
#   'tx',
#   Timestamp('2021-04-24 00:00:00+0000', tz='UTC')),
#  (362723,
#   7311441803,
#   'abilene',
#   11500.0,
#   2014,
#   'honda',
#   'cr-v',
#   'excellent',
#   '4 cylinders',
#   'gas',
#   151299,
#   'clean',
#   'automatic',
#   'fwd',
#   'Unknown',
#   'SUV',
#   'Unknown',
#   "2014 HONDA CR-V LX SUV   Ready To Upgrade Your Ride Today? We Make It Fast & Easy!Call (or text) ☏ (325) 725−8154  Richard Roberts Motors 134 N. Clack Street, Abilene, TX 79603Copy & Paste the URL belowto view more information!http://richardrobertsmotors.com   \t\t\tYear : 2014\t\t\t\tMake : HONDA\t\t\t\tModel : CR-V\t\t\t\tTrim : LX\t\t\t\t   Mileage : 151,299 miles\t\t\t\tTransmission : Automatic\t\t\t\tExterior Color : MAROON\t\t\t\tInterior Color : GRAY\t\t\t\tSeries : LX SUV\t\t\t\tDrivetrain : FWD\t\t\t\tCondition : Excellent\t\t\t\t\tStock ID : 1077\t\t\t\tEngine : 2.4L\t   > > > $11,500 < < <   Description of this HONDA CR-V LX  Nice Honda CRV. Power windows, locks, tilt, cruise, and rear camera. Clean title.Cash, personal check, credit card or outside financing only.  This vehicle qualifies for financing through banks and credit unions.Thank you for you interest.     🚘 Richard Roberts Motors 🚘 ✅ Huge Selection Of Quality Pre-Owned Cars ✅ Leave The Lot With Confidence ✅ Trade-In Your Car Today For A Great Discount  ✅ We Buy Cars Cash  📍 Stop By Today And See Why Our Dealership Is Always The People's Choice💥 Check Out More Of Our Great Cars On Craigslist Just Copy And Paste This Link Into Your Browser 💥 https://abilene.craigslist.org/search/ctd?query=richardrobertsmotors.com     Call (or text)  (325) 725−8154 for quick answers to your questions about this HONDA CR-V LX.   ***** HONDA CR-V LX SUV *****  2015, 2016, 2017, 2014, 2013, 2012, 2011, HONDA CR-V, Accord, CR-V, Civic, Civic Hybrid, Element, Fit, Insight, Pilot, Odyssey, Ridgeline, Accord Crosstour, CR-Z, Crosstour, Fit EV, Accord Hybrid, Accord Plug-In Hybrid   Disclaimer : * Please Note All Inventory And Inventory Pricing Is Subject To Change Please See Dealer For Further Details *     Ready To Upgrade Your Ride Today? We Make It Fast & Easy!Call (or text) ☏ (325) 725−8154  Richard Roberts Motors 134 N. Clack Street, Abilene, TX 79603Copy & Paste the URL belowto view more information!http://richardrobertsmotors.com    2014 14 *HONDA* *CR-V* *Cheap LX* \t\t*Like New 2014 LX SUV* *2.4L* \t\t*Must See 2014 HONDA CR-V LX Gasoline - \t\t2014 HONDA CR-V  cr-v CR-V LX Gasoline SUV Cheap -  \t\t2014 HONDA CR-V (LX) Carfax Gasoline 2.4L -  \t\t2014 HONDA CR-V LX SUV 2.4L Gasoline  -  \t\tHONDA CR-V LX SUV   \t\t*SCHEDULE YOUR TEST DRIVE 2014 HONDA CR-V  2.4L LX Gasoline SUV*   \t\t*HONDA* *CR-V* 2014 HONDA CR-V LX Gasoline SUV   \t\t*2014 HONDA CR-V LX  \t\t*Richard Roberts Motors* *Call (or text) us today at (325) 725−8154.* \t\t2015 HONDA CR-V LX 2.4L - \t\tHave you seen this 2016 HONDA CR-V LX SUV ?  \t\tMust See 2017 HONDA CR-V  CRV crv CRV LX Gasoline SUV  \t\t*For Sale CR-V* *CR-V* *Carfax LX Gasoline SUV  \t\tCome test drive this amazing *HONDA* *CR-V* *(LX)* *Gasoline* SUV LX SUV Gasoline SUV Gasoline* \t\t*(HONDA)* *(CR-V)* *LX* *2.4L* *(GASOLINE)* *Bad Credit* \t\t*Gasoline* *SUV*  *Super Vehicle Gasoline Call (or text) this number (325) 725−8154* *2.4L* *Richard Roberts Motors* * Good Credit* \t\t2014 2013 2012 2011  \t\t*This vehicle is a used HONDA CR-V* *No Credit* \t\t*It is like New LX* *2.4L Gasoline*  \t\t*Gasoline* 2010 2009 2008 2007 2006 2005",
#   'Unknown',
#   'tx',
#   Timestamp('2021-04-23 00:00:00+0000', tz='UTC')),
#  (362763,
#   7308988448,
#   'abilene',
#   11125.0,
#   2014,
#   'toyota',
#   'camry',
#   'good',
#   '4 cylinders',
#   'gas',
#   51534,
#   'clean',
#   'automatic',
#   'fwd',
#   'full-size',
#   'sedan',
#   'grey',
#   '2014 Grey Toyota Camry LE 4 dr with very clean light grey cloth interior. Automatic, Power Windows, Power Seat Drivers side, Power Locks, Mirrors, Tilt, Cruise, A/C, CD,  Steering wheel controls, Blue Tooth / Phone and USB Port, Back up Camera.  Economical 2.5 ltr  4 cylinder engine with (  51,534 miles. ) EPA estimates are 25 to 35 mpg & 27 mpg overall. This car has some minor Hail Damage and is offered at $11,125.00 plus the TT&l   ( Suggested Retail is $13200.00 before TT&l  and highly rated car by Consumers Reports ) Compare the value on this car to others and come check it out! You provide the financing through your bank or credit union etc ! Call or Text John @ 325 665 4176',
#   'Unknown',
#   'tx',
#   Timestamp('2021-04-18 00:00:00+0000', tz='UTC')),
#  (362752,
#   7309998951,
#   'abilene',
#   13500.0,
#   2016,
#   'chrysler',
#   'town & country',
#   'excellent',
#   '6 cylinders',
#   'gas',
#   107699,
#   'clean',
#   'automatic',
#   'fwd',
#   'Unknown',
#   'mini-van',
#   'grey',
#   "2016 CHRYSLER TOWN & COUNTRY TOURING Mini-Van   Ready To Upgrade Your Ride Today? We Make It Fast & Easy!Call (or text) ☏ (325) 725−8154  Richard Roberts Motors 134 N. Clack Street, Abilene, TX 79603Copy & Paste the URL belowto view more information!http://richardrobertsmotors.com   \t\t\tYear : 2016\t\t\t\tMake : CHRYSLER\t\t\t\tModel : TOWN & COUNTRY\t\t\t\tTrim : TOURING\t\t\t\t   Mileage : 107,699 miles\t\t\t\tTransmission : Automatic\t\t\t\tExterior Color : GRAY\t\t\t\tInterior Color : GRAY\t\t\t\tSeries : TOURING Mini-Van\t\t\t\tDrivetrain : FWD\t\t\t\tCondition : Excellent\t\t\t\t\tStock ID : 1076\t\t\t\tEngine : 3.6L\t   > > > $13,500 < < <   Description of this CHRYSLER TOWN & COUNTRY TOURING  Nice Chrysler Town & Country Van. Heated leather seats, heated steering wheel, rear camera, navigation and rear dvd.Cash, personal check, credit card or outside financing only.  This vehicle qualifies for financing through banks and credit unions.Thank you for you interest.     🚘 Richard Roberts Motors 🚘 ✅ Huge Selection Of Quality Pre-Owned Cars ✅ Leave The Lot With Confidence ✅ Trade-In Your Car Today For A Great Discount  ✅ We Buy Cars Cash  📍 Stop By Today And See Why Our Dealership Is Always The People's Choice💥 Check Out More Of Our Great Cars On Craigslist Just Copy And Paste This Link Into Your Browser 💥 https://abilene.craigslist.org/search/ctd?query=richardrobertsmotors.com     Call (or text)  (325) 725−8154 for quick answers to your questions about this CHRYSLER TOWN & COUNTRY TOURING.   ***** CHRYSLER TOWN & COUNTRY TOURING Mini-Van *****  2017, 2018, 2019, 2016, 2015, 2014, 2013, CHRYSLER TOWN & COUNTRY, 200, 300, 300C, Town & Country   Disclaimer : * Please Note All Inventory And Inventory Pricing Is Subject To Change Please See Dealer For Further Details *     Ready To Upgrade Your Ride Today? We Make It Fast & Easy!Call (or text) ☏ (325) 725−8154  Richard Roberts Motors 134 N. Clack Street, Abilene, TX 79603Copy & Paste the URL belowto view more information!http://richardrobertsmotors.com    2016 16 *CHRYSLER* *TOWN & COUNTRY* *Cheap TOURING* \t\t*Like New 2016 TOURING Mini-Van* *3.6L* \t\t*Must See 2016 CHRYSLER TOWN & COUNTRY TOURING Gasoline - \t\t2016 CHRYSLER TOWN & COUNTRY  town & country TOWN & COUNTRY TOURING Gasoline Mini-Van Cheap -  \t\t2016 CHRYSLER TOWN & COUNTRY (TOURING) Carfax Gasoline 3.6L -  \t\t2016 CHRYSLER TOWN & COUNTRY TOURING Mini-Van 3.6L Gasoline  -  \t\tCHRYSLER TOWN & COUNTRY TOURING Mini-Van   \t\t*SCHEDULE YOUR TEST DRIVE 2016 CHRYSLER TOWN & COUNTRY  TOWN&COUNTRY town&country TOWN&COUNTRY 3.6L TOURING Gasoline Mini-Van*   \t\t*CHRYSLER* *TOWN & COUNTRY* 2016 CHRYSLER TOWN & COUNTRY TOURING Gasoline Mini-Van   \t\t*2016 CHRYSLER TOWN & COUNTRY TOURING  \t\t*Richard Roberts Motors* *Call (or text) us today at (325) 725−8154.* \t\t2017 CHRYSLER TOWN & COUNTRY TOURING 3.6L - \t\tHave you seen this 2018 CHRYSLER TOWN & COUNTRY TOURING Mini-Van ?  \t\tMust See 2019 CHRYSLER TOWN & COUNTRY  TOURING Gasoline Mini-Van  \t\t*For Sale TOWN & COUNTRY* *TOWN & COUNTRY* *Carfax TOURING Gasoline Mini-Van  \t\tCome test drive this amazing *CHRYSLER* *TOWN & COUNTRY* *(TOURING)* *Gasoline* Mini-Van TOURING Mini-Van Gasoline Mini-Van Gasoline* \t\t*(CHRYSLER)* *(TOWN & COUNTRY)* *TOURING* *3.6L* *(GASOLINE)* *Bad Credit* \t\t*Gasoline* *Mini-Van*  *Super Vehicle Gasoline Call (or text) this number (325) 725−8154* *3.6L* *Richard Roberts Motors* * Good Credit* \t\t2016 2015 2014 2013  \t\t*This vehicle is a used CHRYSLER TOWN & COUNTRY* *No Credit* \t\t*It is like New TOURING* *3.6L Gasoline*  \t\t*Gasoline* 2012 2011 2010 2009 2008 2007",
#   'Unknown',
#   'tx',
#   Timestamp('2021-04-20 00:00:00+0000', tz='UTC')),
#  (362804,
#   7305927171,
#   'abilene',
#   11850.0,
#   2016,
#   'toyota',
#   'corolla',
#   'like new',
#   '4 cylinders',
#   'gas',
#   30323,
#   'clean',
#   'automatic',
#   'fwd',
#   'sub-compact',
#   'sedan',
#   'silver',
#   'Silver 2016 Toyota Corolla LE 4DR with grey cloth interior. Automatic, Power windows, Mirrors, Locks, Tilt, Cruise, A/C, CD, Phone hook up,  steering wheel controls, and auxiliary port. 1.8 ltr  4 cylinder engine with only 30323 miles.  EPA estimated at 32 mpg overall. This vehicle is rated a Consumers Reports Good Bet for performance and reliability! NADA Clean Retail is $ 14,975.00  before TTL. This is a bargain !!! Good  Title ** Priced at only $11850.00 plus TT&l ** Your Total out the door is $12,774.26  Come check this one out before you buy a new one. You provide the Financing through your bank or credit union etc. Call or Text John @ 325 665 4176',
#   'Unknown',
#   'tx',
#   Timestamp('2021-04-12 00:00:00+0000', tz='UTC')),
#  (362775,
#   7307678518,
#   'abilene',
#   4000.0,
#   2004,
#   'buick',
#   'lesabre',
#   'Unknown',
#   'Unknown',
#   'gas',
#   113201,
#   'clean',
#   'automatic',
#   'Unknown',
#   'Unknown',
#   'Unknown',
#   'Unknown',
#   "$4000.00   2004 Buick Lesabre   V6 3800 engine   Automatic   113k miles   Cold ac and heat   Cloth seats   Smooth running on the hwy like you're riding on air. It has low miles so plenty of life left in this beauty. New front window regulator worh ac blower motor. Perfect for the hwy on those long trips. Dash is peeling up not selling as perfect it does have cosmetic wear. Bring your mechanic for test drive.   Call or txt 04 lesabre   (512)653-0636   Stop by 1842 nrth 1st   Abilene tx 79603",
#   'Unknown',
#   'tx',
#   Timestamp('2021-04-16 00:00:00+0000', tz='UTC')),
#  (362714,
#   7311832851,
#   'abilene',
#   4000.0,
#   2004,
#   'buick',
#   'lesabre',
#   'Unknown',
#   'Unknown',
#   'gas',
#   113201,
#   'clean',
#   'automatic',
#   'Unknown',
#   'Unknown',
#   'Unknown',
#   'Unknown',
#   "$4000.00   2004 Buick Lesabre   V6 3800 engine   Automatic   113k miles   Cold ac and heat   Cloth seats   Smooth running on the hwy like you're riding on air. It has low miles so plenty of life left in this beauty. New front window regulator worh ac blower motor. Perfect for the hwy on those long trips. Dash is peeling up not selling as perfect it does have cosmetic wear. Bring your mechanic for test drive.   Call or txt 04 lesabre   (512)653-0636   Stop by 1842 nrth 1st   Abilene tx 79603",
#   'Unknown',
#   'tx',
#   Timestamp('2021-04-24 00:00:00+0000', tz='UTC')),
#  (362838,
#   7303347398,
#   'abilene',
#   0.0,
#   2018,
#   'Unknown',
#   'peterbilt 579',
#   'Unknown',
#   'Unknown',
#   'diesel',
#   1,
#   'clean',
#   'automatic',
#   'Unknown',
#   'Unknown',
#   'Unknown',
#   'Unknown',
#   '◄ PRICES STARTING AT $57,500 ($57,500 and up, priced according to mileage, subject to change) ◄ MULTIPLE UNITS AVAILABLE! ◄ ARRAY OF MILEAGES - STARTING AT 350K AND UP ◄ VARIETY OF COLORS AVAILABLE!   Engine: PACCAR MX-13 Horsepower: 455 Engine Torque: 1650 Mileage: Starting at 350,000 and up Suspension: FLEX-AIR Transmission: EATON FULLER FAO16810C-EA3 10 SPEED AUTOMATIC Wheelbase: 238" Sleeper Size: RAISED ROOF 80" DOUBLE BUNK Exhaust: HORIZONTAL Bumper: PAINTED OR CHROME (SOME HAVE BUMPER GUARDS) Rear Axle Make: MERITOR Axle Ratio: 3.08 Interior: GRAY Driver Seat: AIR RIDE Radio: SMARTNAV DASH NAVIGATION Fuel Tank Left: 100 GAL Fuel Tank Right: 100 GAL Fifth Wheel: AIR SLIDE Wheels: ALL ALUMINUM Front Tire Size: 22.5" Rear Tire Size: 22.5" Color: SEVERAL COLORS TO CHOOSE FROM! Retarder: JAKE GVWR: 52,000 FA#\'S: 12,000 RA#\'S: 40,000 Fuel Type: DIESEL Drive Line: 6X4 # of Rear Tires: 8  Features: BRAND NEW DUAL DRIVE TIRES. PLATINUM INTERIOR. DOUBLE BUNK. SMARTNAV DASH NAVIGATION. THERMOKING APU\'S. SOME UNITS HAVE BUMPER GUARDS. SOME UNITS HAVE FRIDGES.  Remaining OEM Factory Warranty: BALANCE OF 4 YRS / 600,000 MILES BASIC VEHICLE WARRANTY ON CHASSIS REMAINS + BALANCE OF 4 YRS / 600,000 MILES ENGINE & AFTERTREATMENT WARRANTY REMAINS. EXTENDED WARRANTY AVAILABLE!   ◄ PRICES STARTING AT $57,500 ($57,500 and up, priced according to mileage, subject to change) ◄ MULTIPLE UNITS AVAILABLE! ◄ ARRAY OF MILEAGES - STARTING AT 350K AND UP ◄ VARIETY OF COLORS AVAILABLE!    Please, serious buyer\'s only. Call or text 816-239-2938 Financing is available for those who qualify - Typically requires around a 600 or better credit score and around 20% down, give or take. If you qualify, give me a call! Cash buyer\'s always welcome.   MULTIPLE COLORS AVAILABLE (subject to change): BLACK BLACK CHERRY BLACK SAPPHIRE BLUE CORAL FLAME RED GALAXY BLUE GOLD GRAY GUN METAL JADE MAROON MIDNIGHT GREEN ORCHID RADIANT RED RED SABLE SILVER SLATE GRAY SUBLIME GREEN SUNBURST ORANGE TEAL VIOLET YELLOW',
#   'Unknown',
#   'tx',
#   Timestamp('2021-04-07 00:00:00+0000', tz='UTC')),
#  (362774,
#   7307679085,
#   'abilene',
#   3500.0,
#   2006,
#   'saturn',
#   'ion',
#   'Unknown',
#   'Unknown',
#   'gas',
#   169984,
#   'clean',
#   'automatic',
#   'Unknown',
#   'Unknown',
#   'Unknown',
#   'Unknown',
#   '$3500.00 CASH   2006 Saturn ION   4 cylinder   Automatic   169 k miles   Cloth seats   Cold ac and heat   Nice four door car for the whole family it runs great and looks good also bring your mechanic by and take it for a test ride .good on gas also   Call or text Saturn   512-653-0636  Stop by   LNC auto sales   1842 nrth 1st   Abilene tx 79603',
#   'Unknown',
#   'tx',
#   Timestamp('2021-04-16 00:00:00+0000', tz='UTC')),
#  (362713,
#   7311833290,
#   'abilene',
#   3500.0,
#   2006,
#   'saturn',
#   'ion',
#   'Unknown',
#   'Unknown',
#   'gas',
#   169984,
#   'clean',
#   'automatic',
#   'Unknown',
#   'Unknown',
#   'Unknown',
#   'Unknown',
#   '$3500.00 CASH   2006 Saturn ION   4 cylinder   Automatic   169 k miles   Cloth seats   Cold ac and heat   Nice four door car for the whole family it runs great and looks good also bring your mechanic by and take it for a test ride .good on gas also   Call or text Saturn   512-653-0636  Stop by   LNC auto sales   1842 nrth 1st   Abilene tx 79603',
#   'Unknown',
#   'tx',
#   Timestamp('2021-04-24 00:00:00+0000', tz='UTC')),
#  (362867,
#   7301838920,
#   'abilene',
#   1234567.0,
#   1955,
#   'chevrolet',
#   'Unknown',
#   'Unknown',
#   'Unknown',
#   'other',
#   99999,
#   'missing',
#   'other',
#   'Unknown',
#   'Unknown',
#   'Unknown',
#   'Unknown',
#   'THE 38TH ANNUAL NATIONALLY ADVERTISED BELTON SWAP MEET APRIL 10TH AND 11TH AT LITTLE VALLEY AUTO RANCH LOCATED AT 1151 S WHEAT RD BELTON TEXAS . VENDOR SET-UP FRIDAY APRIL 9TH 9AM-7 PM. VENDOR SPACES 12 X 20 STILL ONLY 25.00 . DRIVING DIRECTIONS GOOGLE LITTLE VALLEY AUTO RANCH . VENDOR REGISTRATION CALL 254-760-7431 CARS PARTS ANTIQUES AND COLLECTABLES WILL BE FEATURED IN OUR 38TH YEAR. HELP KEEP AMERICA RACIN RODDIN AND RESTORIN. PLEASE FEEL FREE TO SHARE AND PASS AROUND',
#   'Unknown',
#   'tx',
#   Timestamp('2021-04-04 00:00:00+0000', tz='UTC')),
#  (362837,
#   7303378226,
#   'abilene',
#   1234567.0,
#   1955,
#   'chevrolet',
#   'Unknown',
#   'Unknown',
#   'Unknown',
#   'other',
#   99999,
#   'missing',
#   'other',
#   'Unknown',
#   'Unknown',
#   'Unknown',
#   'Unknown',
#   'THE 38TH ANNUAL NATIONALLY ADVERTISED BELTON SWAP MEET APRIL 10TH AND 11TH AT LITTLE VALLEY AUTO RANCH LOCATED AT 1151 S WHEAT RD BELTON TEXAS . VENDOR SET-UP FRIDAY APRIL 9TH 9AM-7 PM. VENDOR SPACES 12 X 20 STILL ONLY 25.00 . DRIVING DIRECTIONS GOOGLE LITTLE VALLEY AUTO RANCH . VENDOR REGISTRATION CALL 254-760-7431 CARS PARTS ANTIQUES AND COLLECTABLES WILL BE FEATURED IN OUR 38TH YEAR. HELP KEEP AMERICA RACIN RODDIN AND RESTORIN. PLEASE FEEL FREE TO SHARE AND PASS AROUND',
#   'Unknown',
#   'tx',
#   Timestamp('2021-04-07 00:00:00+0000', tz='UTC')),
#  (362822,
#   7304059291,
#   'abilene',
#   1234567.0,
#   1955,
#   'chevrolet',
#   'Unknown',
#   'Unknown',
#   'Unknown',
#   'other',
#   99999,
#   'missing',
#   'other',
#   'Unknown',
#   'Unknown',
#   'Unknown',
#   'Unknown',
#   'THE 38TH ANNUAL NATIONALLY ADVERTISED BELTON SWAP MEET APRIL 10TH AND 11TH AT LITTLE VALLEY AUTO RANCH LOCATED AT 1151 S WHEAT RD BELTON TEXAS . VENDOR SET-UP FRIDAY APRIL 9TH 9AM-7 PM. VENDOR SPACES 12 X 20 STILL ONLY 25.00 . DRIVING DIRECTIONS GOOGLE LITTLE VALLEY AUTO RANCH . VENDOR REGISTRATION CALL 254-760-7431 CARS PARTS ANTIQUES AND COLLECTABLES WILL BE FEATURED IN OUR 38TH YEAR. HELP KEEP AMERICA RACIN RODDIN AND RESTORIN. PLEASE FEEL FREE TO SHARE AND PASS AROUND',
#   'Unknown',
#   'tx',
#   Timestamp('2021-04-09 00:00:00+0000', tz='UTC')),
#  (362700,
#   7313061478,
#   'abilene',
#   20995.0,
#   2008,
#   'ford',
#   'super duty f-350 srw',
#   'excellent',
#   '8 cylinders',
#   'diesel',
#   211298,
#   'clean',
#   'automatic',
#   '4wd',
#   'full-size',
#   'pickup',
#   'black',
#   "2008 Ford Super Duty F-350_ F350_ f350_ F\xa0350_ SRW 4WD Crew Cab 172 Lariat   📲 ☎ Call or text Lonestar Car & Truck - (972) 694-6950 to test drive this car.   2008 Ford F350 Lariat, 100% New 37's Clean inside and out, Navigation, Heated seats, Power Options, Well taken care of please call or text 972-818-5389 Lonestar Car & Truck    \t\t\tYear : 2008\t\t\t\tMake : Ford\t\t\t\tModel : Super Duty F-350 SRW\t\t\t\tTrim : 4WD Crew Cab 172 Lariat\t\t\t\t   Mileage : 211,298 miles\t\t\t\tTransmission : Automatic\t\t\t\tExterior Color : Black\t\t\t\tInterior Color : Tan\t\t\t\tSeries : 4WD Crew Cab 172 Lariat Pickup\t\t\t\tDrivetrain : 4WD\t\t\t\tCondition : Excellent\t\t\t\tVIN : 1FTWW31R98EA47287\t\t\t\tStock ID : 000852\t\t\t\tEngine : 6.4L 350.0hp\t   24/7 Anytime (972) 694-6950 Call us or text now!!Lonestar Car And Truck in Carrollton Tx is a family owned and operated business. We are committed to delivering the best possible service! Our mission is to provide Dallas and Fort Worth with hand picked, quality vehicles at no hassle prices. We can offer pre-purchase inspections, airport shuttles, financing, warranties and more! We offer competitive, on-site financing to fit all types of buyers! Get pre-approved at: www.lonestarcarandtruck.com/credit-application/ All vehicles are priced for QUICK SALE. All REASONABLE offers will be considered! Hand picked, top-quality, fully inspected Certified Pre-Owned CARFAX vehicles! We offer extended warranties! Free CARFAX report available! Trade-ins welcome! We buy used vehicles! We cater to local customers and out-of-town customers! Customer service is our primary goal! You won't be disappointed! Se habla espanol!🚩 CHECK OUT OUR REVIEWS ON FACEBOOK: https://www.facebook.com/Lonestar-Car-And-Truck-1752163285006426/💬💬💬 HABLAMOS ESPANOL.. 💬💬💬Tenemos enganches bajos, pagos bajos y aceptamos todos typos de creditos. Nosotros especializamos en la adquisicion de financiamienton para clientes sin la documentacion adecuada.Pero debemos enorgullecernos del servico al cliente que brindamos a todos nuestros clientes.Para mas informacion, Llame o Mande texto al ☎ (972) 694-6950✅ FOR MORE OF OUR ADS ON CRAIGSLIST, CHECK OUT THIS PAGE :https://austin.craigslist.org/search/ctd?query=www.ilonestarcarandtruck.com24/7 Anytime (972) 694-6950 Call us now!!      More vehicle details: www.lonestarcarandtruck.com/inventory/view/13824849     Address: 1912 Old Denton Rd, Carrollton, TX 75006\tPhone: (972) 694-6950\tWebsite: http://LONESTARCARANDTRUCK.COM/cars/13824849    📲 ☎️ Call (972) 694-6950 for quick answers to your questions about this Ford Super Duty F-350 SRW. Your message will always be answered by a real human - never an automated system.     2009, 2010, 2011, 2008, 2007, 2006, 2005, Ford Super Duty F-350 SRW, Crown Victoria, E150, Escape Hybrid, Escape, F150, F350, Excursion, Expedition, Explorer, Explorer Sport Trac, F250, Focus, Freestyle, Five Hundred, Freestar, GT, Mustang, Ranger, Taurus, Thunderbird, E350, E250, E350 Super Duty, Fusion, Edge, Expedition EL, F450, Taurus X, Flex, Fusion Hybrid, Transit Connect, Fiesta Disclaimer :",
#   'Unknown',
#   'tx',
#   Timestamp('2021-04-26 00:00:00+0000', tz='UTC')),
#  (362699,
#   7313061591,
#   'abilene',
#   18995.0,
#   2010,
#   'ford',
#   'super duty f-350 drw',
#   'excellent',
#   '8 cylinders',
#   'diesel',
#   169999,
#   'clean',
#   'automatic',
#   'rwd',
#   'full-size',
#   'pickup',
#   'white',
#   "2010 Ford Super Duty F-350_ F350_ f350_ F\xa0350_ DRW 2WD Crew Cab 172 XL   📲 ☎ Call or text Lonestar Car & Truck - (972) 694-6950 to test drive this car.   2010 Ford F350 XL Immaculate, Dully, Clean inside and out, Pease call or text 972-818-5389 We have financing options and ship nation wide. Lonestar Car & Truck    \t\t\tYear : 2010\t\t\t\tMake : Ford\t\t\t\tModel : Super Duty F-350 DRW\t\t\t\tTrim : 2WD Crew Cab 172 XL\t\t\t\t   Mileage : 169,999 miles\t\t\t\tTransmission : Automatic\t\t\t\tExterior Color : White\t\t\t\tInterior Color : Gray\t\t\t\tSeries : 2WD Crew Cab 172 XL Pickup\t\t\t\tDrivetrain : RWD\t\t\t\tCondition : Excellent\t\t\t\tVIN : 1FTWW3CR9AEB05371\t\t\t\tStock ID : 000880\t\t\t\tEngine : 6.4L 350.0hp\t   24/7 Anytime (972) 694-6950 Call us or text now!!Lonestar Car And Truck in Carrollton Tx is a family owned and operated business. We are committed to delivering the best possible service! Our mission is to provide Dallas and Fort Worth with hand picked, quality vehicles at no hassle prices. We can offer pre-purchase inspections, airport shuttles, financing, warranties and more! We offer competitive, on-site financing to fit all types of buyers! Get pre-approved at: www.lonestarcarandtruck.com/credit-application/ All vehicles are priced for QUICK SALE. All REASONABLE offers will be considered! Hand picked, top-quality, fully inspected Certified Pre-Owned CARFAX vehicles! We offer extended warranties! Free CARFAX report available! Trade-ins welcome! We buy used vehicles! We cater to local customers and out-of-town customers! Customer service is our primary goal! You won't be disappointed! Se habla espanol!🚩 CHECK OUT OUR REVIEWS ON FACEBOOK: https://www.facebook.com/Lonestar-Car-And-Truck-1752163285006426/💬💬💬 HABLAMOS ESPANOL.. 💬💬💬Tenemos enganches bajos, pagos bajos y aceptamos todos typos de creditos. Nosotros especializamos en la adquisicion de financiamienton para clientes sin la documentacion adecuada.Pero debemos enorgullecernos del servico al cliente que brindamos a todos nuestros clientes.Para mas informacion, Llame o Mande texto al ☎ (972) 694-6950✅ FOR MORE OF OUR ADS ON CRAIGSLIST, CHECK OUT THIS PAGE :https://austin.craigslist.org/search/ctd?query=www.ilonestarcarandtruck.com24/7 Anytime (972) 694-6950 Call us now!!      More vehicle details: www.lonestarcarandtruck.com/inventory/view/14001950     Address: 1912 Old Denton Rd, Carrollton, TX 75006\tPhone: (972) 694-6950\tWebsite: http://LONESTARCARANDTRUCK.COM/cars/14001950    📲 ☎️ Call (972) 694-6950 for quick answers to your questions about this Ford Super Duty F-350 DRW. Your message will always be answered by a real human - never an automated system.     2011, 2012, 2013, 2010, 2009, 2008, 2007, Ford Super Duty F-350 DRW, Crown Victoria, Edge, E150, Escape Hybrid, Expedition EL, Escape, F150, F350, Expedition, Explorer, Explorer Sport Trac, F250, Focus, Freestyle, Five Hundred, Freestar, Fusion, Mustang, Ranger, Taurus, E350, E250, E350 Super Duty, F450, Taurus X, Flex, Fusion Hybrid, Transit Connect, Fiesta, C-Max, Focus Electric, Focus ST, C-Max Hybrid, C-Max Energi, Fusion Energi Disclaimer :",
#   'Unknown',
#   'tx',
#   Timestamp('2021-04-26 00:00:00+0000', tz='UTC')),
#  (362697,
#   7313061870,
#   'abilene',
#   38995.0,
#   2012,
#   'ram',
#   '3500',
#   'excellent',
#   '6 cylinders',
#   'diesel',
#   127999,
#   'clean',
#   'automatic',
#   '4wd',
#   'full-size',
#   'Unknown',
#   'white',
#   "2012 RAM 3500 4WD Reg Cab 140.5    📲 ☎ Call or text Lonestar Car & Truck - (972) 694-6950 to test drive this car.    Lonestar Car & Truck    \t\t\tYear : 2012\t\t\t\tMake : RAM\t\t\t\tModel : 3500\t\t\t\tTrim : 4WD Reg Cab 140.5 \t\t\t\t   Mileage : 127,999 miles\t\t\t\tTransmission : Automatic\t\t\t\tExterior Color : White\t\t\t\tInterior Color : Gray\t\t\t\tSeries : 4WD Reg Cab 140.5  \t\t\t\tDrivetrain : 4WD\t\t\t\tCondition : Excellent\t\t\t\tVIN : 3C63DRAL1CG191790\t\t\t\tStock ID : 000891\t\t\t\tEngine : 6.7L 350.0hp\t   24/7 Anytime (972) 694-6950 Call us or text now!!Lonestar Car And Truck in Carrollton Tx is a family owned and operated business. We are committed to delivering the best possible service! Our mission is to provide Dallas and Fort Worth with hand picked, quality vehicles at no hassle prices. We can offer pre-purchase inspections, airport shuttles, financing, warranties and more! We offer competitive, on-site financing to fit all types of buyers! Get pre-approved at: www.lonestarcarandtruck.com/credit-application/ All vehicles are priced for QUICK SALE. All REASONABLE offers will be considered! Hand picked, top-quality, fully inspected Certified Pre-Owned CARFAX vehicles! We offer extended warranties! Free CARFAX report available! Trade-ins welcome! We buy used vehicles! We cater to local customers and out-of-town customers! Customer service is our primary goal! You won't be disappointed! Se habla espanol!🚩 CHECK OUT OUR REVIEWS ON FACEBOOK: https://www.facebook.com/Lonestar-Car-And-Truck-1752163285006426/💬💬💬 HABLAMOS ESPANOL.. 💬💬💬Tenemos enganches bajos, pagos bajos y aceptamos todos typos de creditos. Nosotros especializamos en la adquisicion de financiamienton para clientes sin la documentacion adecuada.Pero debemos enorgullecernos del servico al cliente que brindamos a todos nuestros clientes.Para mas informacion, Llame o Mande texto al ☎ (972) 694-6950✅ FOR MORE OF OUR ADS ON CRAIGSLIST, CHECK OUT THIS PAGE :https://austin.craigslist.org/search/ctd?query=www.ilonestarcarandtruck.com24/7 Anytime (972) 694-6950 Call us now!!      More vehicle details: www.lonestarcarandtruck.com/inventory/view/14160980     Address: 1912 Old Denton Rd, Carrollton, TX 75006\tPhone: (972) 694-6950\tWebsite: http://LONESTARCARANDTRUCK.COM/cars/14160980    📲 ☎️ Call (972) 694-6950 for quick answers to your questions about this RAM 3500. Your message will always be answered by a real human - never an automated system.     2013, 2014, 2015, 2012, 2011, 2010, 2009, RAM 3500, 1500, 2500, 3500, Cargo, ProMaster 2500, ProMaster 3500, ProMaster 1500, ProMaster 2500 Window Van Disclaimer :",
#   'Unknown',
#   'tx',
#   Timestamp('2021-04-26 00:00:00+0000', tz='UTC')),
#  (362698,
#   7313061731,
#   'abilene',
#   21995.0,
#   2014,
#   'jeep',
#   'wrangler',
#   'excellent',
#   '6 cylinders',
#   'gas',
#   106377,
#   'clean',
#   'automatic',
#   '4wd',
#   'Unknown',
#   'SUV',
#   'white',
#   "2014 Jeep WRANGLER SPORT   📲 ☎ Call or text Lonestar Car & Truck - (972) 694-6950 to test drive this car.   2014 Jeep Wrangler Sport, Clean inside and out. Clean White exterior, Black 3 piece removable hartop, Nice wheels and tires runs and drives great. Please call or text 972-818-5389 Lonestar Car & Truck    \t\t\tYear : 2014\t\t\t\tMake : Jeep\t\t\t\tModel : WRANGLER\t\t\t\tTrim : SPORT\t\t\t\t   Mileage : 106,377 miles\t\t\t\tTransmission : Automatic\t\t\t\tExterior Color : White\t\t\t\tInterior Color : Black\t\t\t\tSeries : SPORT SUV\t\t\t\tDrivetrain : 4WD\t\t\t\tCondition : Excellent\t\t\t\tVIN : 1C4AJWAG0EL245211\t\t\t\tStock ID : 000887\t\t\t\tEngine : 3.6L\t   24/7 Anytime (972) 694-6950 Call us or text now!!Lonestar Car And Truck in Carrollton Tx is a family owned and operated business. We are committed to delivering the best possible service! Our mission is to provide Dallas and Fort Worth with hand picked, quality vehicles at no hassle prices. We can offer pre-purchase inspections, airport shuttles, financing, warranties and more! We offer competitive, on-site financing to fit all types of buyers! Get pre-approved at: www.lonestarcarandtruck.com/credit-application/ All vehicles are priced for QUICK SALE. All REASONABLE offers will be considered! Hand picked, top-quality, fully inspected Certified Pre-Owned CARFAX vehicles! We offer extended warranties! Free CARFAX report available! Trade-ins welcome! We buy used vehicles! We cater to local customers and out-of-town customers! Customer service is our primary goal! You won't be disappointed! Se habla espanol!🚩 CHECK OUT OUR REVIEWS ON FACEBOOK: https://www.facebook.com/Lonestar-Car-And-Truck-1752163285006426/💬💬💬 HABLAMOS ESPANOL.. 💬💬💬Tenemos enganches bajos, pagos bajos y aceptamos todos typos de creditos. Nosotros especializamos en la adquisicion de financiamienton para clientes sin la documentacion adecuada.Pero debemos enorgullecernos del servico al cliente que brindamos a todos nuestros clientes.Para mas informacion, Llame o Mande texto al ☎ (972) 694-6950✅ FOR MORE OF OUR ADS ON CRAIGSLIST, CHECK OUT THIS PAGE :https://austin.craigslist.org/search/ctd?query=www.ilonestarcarandtruck.com24/7 Anytime (972) 694-6950 Call us now!!      More vehicle details: www.lonestarcarandtruck.com/inventory/view/14073833     Address: 1912 Old Denton Rd, Carrollton, TX 75006\tPhone: (972) 694-6950\tWebsite: http://LONESTARCARANDTRUCK.COM/cars/14073833    📲 ☎️ Call (972) 694-6950 for quick answers to your questions about this Jeep WRANGLER. Your message will always be answered by a real human - never an automated system.     2015, 2016, 2017, 2014, 2013, 2012, 2011, Jeep WRANGLER, Compass, Grand Cherokee, Liberty, Patriot, Wrangler, Wrangler Unlimited, Cherokee, Renegade Disclaimer :",
#   'Unknown',
#   'tx',
#   Timestamp('2021-04-26 00:00:00+0000', tz='UTC')),
#  (362693,
#   7313284923,
#   'abilene',
#   30998.0,
#   2010,
#   'ford',
#   'f-150',
#   'Unknown',
#   'Unknown',
#   'gas',
#   96462,
#   'clean',
#   'automatic',
#   '4wd',
#   'Unknown',
#   'truck',
#   'black',
#   "Stanley Ford Eastland address:    1308 E Main St Eastland TX, 76448phone:      ☎ (254) 233-7208 ext 43text:       Text 43 to (254) 233-7208 for more details  link:       https://25045.solidautonet.com/vslp/45017169/2/22305217/43  contact:    Chris Koster   2010 FORD F-150 SVT RAPTOR Vehicle InfoStock #: FC78460TVIN: 1FTEX1E63AFC78460Condition: UsedOdometer: 96462DrivetrainEngine: 6.2 liter 8 Cylinder EngineCylinders: 8Fuel Type: Gasoline FuelTransmission: 6-SPEED ELECTRONIC AUTOMATIC  W/OD, TOW & HAUL MODTransmission Type: 6-SPEED ELECTRONIC AUTOMATIC  W/OD, TOW & HAUL MODDrivetrain: 4WDBody & InteriorExterior Color: BlackOEM Color Name: Tuxedo BlackDoors: 2Description It has satellite radio capabilities. This vehicle has four wheel drive capabilities. It has an elegant black exterior finish. This 1/2 ton pickup has a 6.2 liter 8 Cylinder Engine high output engine. Anti-lock brakes will help you stop in an emergency. The Electronic Stability Control will keep you on your intended path. This 2010 Ford F-150  is equipped with a gasoline engine. It comes with running boards already installed. The shiftable automatic in the vehicle gives you to option to control your gears manually without having to give up the convenience of an automatic transmission. Half ton trucks are the most functional trucks for all purposes.Options4-wheel drive.,                 Trailer sway control.,          Front/rear tow hooks.,          HD skid plates.,                5.5' pickup box.,               Flared pickup box outers.,      (4) pickup box tie-down hooks., Unique tie rods.,               6950# GVWR.,                    1020# maximum payload.,         Pwr rack & pinion steering.,    Pwr front & rear disc brakes.,  Hill decent/off road mode.,     Unique dual outlet muffler.,    2-ton jack.,                    Full-size spare tire w/lock.,   underframe winch-type carrier., safety catch.,                  Hood w/air extractors.,         Cast aluminum running boards.,  Black front/rear stone cuffs.,  Outer scuff pad.,               Brick wall front grille.,       Autolamp.,                      automatic on/off headlamps.,    Integrated marker lights.,      Rear privacy tint glass.,       Black door & tailgate handles., Unique tailgate badge.,         SIRIUS satellite radio.,        roof-mounted antenna.,          Tilt steering column.,          Gauges.,                        fuel gauge.,                    voltmeter.,                     oil pressure.,                  engine coolant temp.,           speedometer.,                   tachometer.,                    odometer.,                      Display center.,                Customer info display.,         Outside temp gauge.,            Delayed accessory pwr.,         Rear door cupholders.,          Console top switches.,          hill decent.,                   easy off road mode.,            aux switch pack.,               MyKey system.,                  top speed limiter.,             audio volume limiter.,          early low fuel warning.,        programmable sound chimes.,     Beltminder w/audio mute.,       SOS post crash alert system.,   height adjusters.,              pretensioners.,                 energy management retractors.,  Rear door child safety locks.,  Dual note horn.,                72-amp/hr (650CCA) maintenance-free battery.,                   Rear suspension w/unique leaf springs.,                         Long travel suspension w/unique front upper/lower control arms., Steering rack travel/boost curve.,                              Easy Fuel capless fuel filler system.,                          LT315/70R17 all-terrain BSW tires.,                             17' cast aluminum wheels w/painted & machined finish.,          Front/rear microcellular jounce bumpers.,                       Unique front bumper w/foundry finish & body-color fascia.,      Unique rear bumper w/painted foundry finish.,                   Unique front/rear wheel lip moldings w/foundry finish.,          ...
#   'Unknown',
#   'tx',
#   Timestamp('2021-04-27 00:00:00+0000', tz='UTC')),
#  (362841,
#   7303091561,
#   'abilene',
#   14995.0,
#   2011,
#   'ram',
#   'pickup',
#   'Unknown',
#   'Unknown',
#   'gas',
#   106263,
#   'clean',
#   'automatic',
#   'rwd',
#   'Unknown',
#   'truck',
#   'green',
#   'Stanley Ford Eastland address:    1308 E Main St Eastland TX, 76448phone:      ☎ (254) 233-7208 ext 19text:       Text 19 to (254) 233-7208 for more details  link:       https://25045.dealerresources.net/p/44821942/2/22281101/19  contact:    Chris Koster   2011 DODGE RAM PICKUP ST Vehicle InfoStock #: S529926TVIN: 1D7RB1GK7BS529926Condition: UsedOdometer: 106263Fuel Efficiency: 14/20DrivetrainEngine: 3.7 liter V6 Cylinder EngineCylinders: 6Fuel Type: Gasoline FuelTransmission: 4-SPEED VLP AUTOMATICTransmission Type: 4-SPEED VLP AUTOMATICDrivetrain: RWDBody & InteriorExterior Color: GreenOEM Color Name: Hunter Green PearlInterior Color: Dark Slate/Medium GraystoneDoors: 4Description Summary**ONE OWNER**, **CLEAN AUTOCHECK**, BLUETOOTH for Hands-Free Phone, AUXILIARY INPUT, POWER EQUIPMENTVehicle DetailsWhy Buy Stanley?CONSIDER IT COVERED: We offer a 3 month/3,000 mile limited warranty with each and every vehicle. Take on the road, not the stress. (Excludes vehicles over 10 years and/or 130,000 milesNot all Vehicles will qualify, please see dealership for the complete list of Eligible Vehicles details.)SERVICE: Our technicians run a rigorous 172-point inspection and all factory recalls are performed before sale.LOCATION, LOCATION, LOCATION! Know exactly what you want but don\'t see it at your closest Stanley dealership? Don\'t let that stop you; we will ship any vehicle at one of our other locations to your hometown Stanley dealership. Start shopping the entire inventory at stanleyautogroup.com.FINANCE FINESSE: Find the perfect financing fit you\'re comfortable with through a wide range of various banks that meet all credit needs. Want warranty, GAP, or added aftermarket parts & upgrades? Pick our brain until you know all of the ins and outs. WANT TO SAVE TIME? Of course you do, who doesn\'t? Fill out our online credit application and get pre-approved!MORE BANG FOR YOUR BUCK: Do you have a trade in? WE WANT IT! Let us give you top dollar for your vehicle to get you one step closer to your dream car.BECOME A PART OF THE FAMILY: Our staff is ready to serve you, providing outstanding customer service to fit your every need to exceed your expectations from beginning to end. EquipmentThe satellite radio system in this model gives you access to hundreds of nation-wide radio stations with a clear digital signal. Enjoy the incredible handling with the rear wheel drive on this Dodge Ram Pickup. This unit shines with a refined green finish. This unit has a 3.7 liter V6 Cylinder Engine high output engine. This Dodge Ram Pickup has an automatic transmission. Enjoy the tried and true gasoline engine in it. Anti-lock brakes will help you stop in an emergency. Big enough to tow or haul, this unit has the space, power and durability for anyone.PackagesCHROME APPEARANCE GROUP: 17" x 8" steel chrome clad wheels; bright front bumper; bright rear bumper. ST POPULAR EQUIPMENT GROUP: cloth seats; SIRIUS satellite radio w/1-year radio service; speed control; carpeted floor covering; front/rear floor mats. 17" X 8" STEEL CHROME CLAD WHEELS. ANTI-SPIN DIFFERENTIAL REAR AXLE. SPEED CONTROL. Equipment listed is based on original vehicle build. Please confirm the accuracy of the included equipment by calling the dealer prior to purchase.Optionsx 8&quot.,                      steel chrome clad wheels.,      bright front bumper.,           bright rear bumper.,            speed control.,                 carpeted floor covering.,       front/rear floor mats.,         SPEED CONTROL.,                 3.55 axle ratio.,               Aux transmission oil cooler.,   Rear wheel drive.,              160-amp alternator.,            7-pin wiring harness.,          6\'4\' pickup box.,               HD front shock absorbers.,      HD rear shock absorbers.,       Front stabilizer bar.,          Rear stabilizer bar.,           Pwr rack & pinion steering.,    Anti-lock 4-wheel disc brakes., (4) conventional doors.,        17\' steel spare wheel.,         Full-size spare  ...
#   'Unknown',
#   'tx',
#   Timestamp('2021-04-07 00:00:00+0000', tz='UTC')),
#  (362708,
#   7312294967,
#   'abilene',
#   16998.0,
#   2012,
#   'chevrolet',
#   'tahoe',
#   'Unknown',
#   'Unknown',
#   'gas',
#   152037,
#   'clean',
#   'automatic',
#   'rwd',
#   'Unknown',
#   'SUV',
#   'white',
# ...
#   'Unknown',
#   'oh',
#   Timestamp('2021-05-02 00:00:00+0000', tz='UTC')),
#  (288345,
#   7302509033,
#   'akron / canton',
#   38995.0,
#   2013,
#   'ford',
#   'f-250 sd',
#   'Unknown',
#   'Unknown',
#   'gas',
#   143822,
#   'clean',
#   'automatic',
#   'Unknown',
#   'Unknown',
#   'other',
#   'red',
#   '2013 Ford F-250 F250 F 250 SD Lariat Crew Cab 4WD     Offered by: R21 Motorsports — (330) 281-4072  — $38,995     In an effort to provide the best response time possible to our Facebook Marketplace customers we are asking that you temporarily discontinue use of the automated "Is This Still Available" tab on marketplace.  Our inventory feed updates several times throughout the day.  This will help our team to better assist you with your sales, selection and technical questions.  6.7L DIESEL ENGINE, 4 WHEEL DRIVE, TOW PACKAGE, ALLOY WHEELS, RUNNING BOARDS, POWER SUNROOF, BLUETOOTH, LEATHER SEATS, HEATED SEATS,  AND MORE.... CALL US TODAY AT 330-854-5380! ASK ABOUT OUR TRUCK FINANCING PROGRAM & NATIONWIDE TRUCK EXTENDED SERVICE CONTRACTS ....IF R21 MOTORSPORTS HAS THE OPPORTUNITY TO HELP YOU IN THESE DIFFICULT TIMES ...WE WILL DO OUR BEST TO PROVIDE YOU FAIR, HONEST AND STRAIGHT FORWARD TRANSACTION ....LOOK FORWARD TO HEARING FROM YOU AND PLEASE TAKE CARE..   R21 Motorsports    Year: 2013 Make: Ford Model: F-250 SD Series: Lariat Crew Cab 4WD  VIN: 1FT7W2BT7DEB82692  Stock #: 18943 Condition: Used Mileage: 143,822  Exterior: RED  Interior: BLACK  Body: CREW CAB PICKUP 4-DR  Transmission: 6-Speed Automatic  Engine: 6.7L V8 OHV 16V DIESEL     We have Financing for everyone and over 100 trucks and vehicles to choose from here at R21 Motorsports!  Call us at 330-281-4072, or text us 24/7!!   More vehicle details: r21-motorsports.hammerwebsites.net/v/mf1IV8u6  Address: 5315 Butterbridge Rd NW Canal Fulton, OH 44614 Phone: (330) 281-4072  Website: www.r21motorsports.com/      📲 ☎️ Call or text (330) 281-4072 for quick answers to your questions about this Ford F-250 SD Your message will always be answered by a real human — never an automated system.     Disclaimer: R21 Motorsports will never sell, share, or spam your mobile number. Standard text messaging rates may apply. Vehicles are described to the best of our abilities, please call to verify information, pricing, and availability.      2013 Ford F-250 SD Lariat Crew Cab 4WD  e0d02ac1ac4a4eb4b47c15ebaaae2cd9',
#   'Unknown',
#   'oh',
#   Timestamp('2021-04-06 00:00:00+0000', tz='UTC')),
#  (287759,
#   7306947551,
#   'akron / canton',
#   44995.0,
#   2013,
#   'ford',
#   'f-250 sd',
#   'Unknown',
#   'Unknown',
#   'gas',
#   89500,
#   'clean',
#   'automatic',
#   'Unknown',
#   'Unknown',
#   'other',
#   'black',
#   '2013 Ford F-250 F250 F 250 SD King Ranch Crew Cab 4WD     Offered by: R21 Motorsports — (330) 281-4072 — $44,995     In an effort to provide the best response time possible to our Facebook Marketplace customers we are asking that you temporarily discontinue use of the automated "Is This Still Available" tab on marketplace.  Our inventory feed updates several times throughout the day.  This will help our team to better assist you with your sales, selection and technical questions.  TEXAS TRUCK.... 6.7L DIESEL ENGINE, 4 WHEEL DRIVE, TOW PACKAGE, ALLOY WHEELS, NAVIGATION SYSTEM, POWER SUNROOF, HEATED REAR SEATS, RUNNING BOARDS, BED LINER, LEATHER SEATS, POWER SEATS, HEATED SEATS, FX4 OFF-ROAD PACKAGE, POWER SLIDING REAR WINDOW, AND MORE...CLEAN AUTOCHECK HISTORY AND 1-OWNER!!!  CALL US AT 330-854-5380...   R21 Motorsports    Year: 2013 Make: Ford Model: F-250 SD Series: King Ranch Crew Cab 4WD VIN: 1FT7W2BT3DEA31199 Stock #: 18952 Condition: Used Mileage: 89,500  Exterior: BLACK Interior: BLACK Body: CREW CAB PICKUP 4-DR Transmission: 6-Speed Automatic Engine: 6.7L V8 OHV 16V DIESEL      We have Financing for everyone and over 100 trucks and vehicles to choose from here at R21 Motorsports!  Call us at 330-281-4072, or text us 24/7!!       More vehicle details: r21-motorsports.hammerwebsites.net/v/zclg6qp-     Address: 5315 Butterbridge Rd NW Canal Fulton, OH 44614   Phone: (330) 281-4072     Website: www.r21motorsports.com/      📲 ☎️ Call or text (330) 281-4072 for quick answers to your questions about this Ford F-250 SD Your message will always be answered by a real human — never an automated system.     Disclaimer: R21 Motorsports will never sell, share, or spam your mobile number. Standard text messaging rates may apply. Vehicles are described to the best of our abilities, please call to verify information, pricing, and availability.      2013 Ford F-250 SD King Ranch Crew Cab 4WD   8554abc69d0845c38d2139dbce02d992',
#   'Unknown',
#   'oh',
#   Timestamp('2021-04-14 00:00:00+0000', tz='UTC')),
#  (287758,
#   7306947754,
#   'akron / canton',
#   40995.0,
#   2013,
#   'ford',
#   'f-250 sd',
#   'Unknown',
#   'Unknown',
#   'gas',
#   116905,
#   'clean',
#   'automatic',
#   'Unknown',
#   'Unknown',
#   'other',
#   'white',
#   '2013 Ford F-250 F250 F 250 SD Lariat Crew Cab 4WD     Offered by: R21 Motorsports — (330) 281-4072 — $40,995     In an effort to provide the best response time possible to our Facebook Marketplace customers we are asking that you temporarily discontinue use of the automated "Is This Still Available" tab on marketplace.  Our inventory feed updates several times throughout the day.  This will help our team to better assist you with your sales, selection and technical questions.  ** TEXAS TRUCK **...6.7L DIESEL ENGINE, 4 WHEEL DRIVE, TOW PACKAGE, ALLOY WHEELS, POWER SUNROOF, LEATHER SEATS, HEATED SEATS, NAVIGATION SYSTEM, BLUETOOTH, FX4 OFF-ROAD PACKAGE, AND MUCH MORE... BEAUTIFUL TRUCK! ..CALL US TODAY AT 330-854-5380! ASK ABOUT OUR TRUCK FINANCING PROGRAM & NATIONWIDE TRUCK EXTENDED SERVICE CONTRACTS ....IF R21 MOTORSPORTS HAS THE OPPORTUNITY TO HELP YOU IN THESE DIFFICULT TIMES ...WE WILL DO OUR BEST TO PROVIDE YOU FAIR, HONEST AND STRAIGHT FORWARD TRANSACTION ....LOOK FORWARD TO HEARING FROM YOU AND PLEASE TAKE CARE..   R21 Motorsports    Year: 2013 Make: Ford Model: F-250 SD Series: Lariat Crew Cab 4WD VIN: 1FT7W2BT3DEA65983 Stock #: 18934 Condition: Used Mileage: 116,905  Exterior: WHITE Interior: TAN Body: CREW CAB PICKUP 4-DR Transmission: 6-Speed Automatic Engine: 6.7L V8 OHV 16V DIESEL      We have Financing for everyone and over 100 trucks and vehicles to choose from here at R21 Motorsports!  Call us at 330-281-4072, or text us 24/7!!       More vehicle details: r21-motorsports.hammerwebsites.net/v/rHkW_X-_     Address: 5315 Butterbridge Rd NW Canal Fulton, OH 44614   Phone: (330) 281-4072     Website: www.r21motorsports.com/      📲 ☎️ Call or text (330) 281-4072 for quick answers to your questions about this Ford F-250 SD Your message will always be answered by a real human — never an automated system.     Disclaimer: R21 Motorsports will never sell, share, or spam your mobile number. Standard text messaging rates may apply. Vehicles are described to the best of our abilities, please call to verify information, pricing, and availability.      2013 Ford F-250 SD Lariat Crew Cab 4WD   cae9bffa0fc947f482bcafe9be308655',
#   'Unknown',
#   'oh',
#   Timestamp('2021-04-14 00:00:00+0000', tz='UTC')),
#  (286527,
#   7315398718,
#   'akron / canton',
#   29995.0,
#   2013,
#   'ford',
#   'f-350 sd',
#   'Unknown',
#   'Unknown',
#   'gas',
#   85450,
#   'clean',
#   'automatic',
#   'Unknown',
#   'Unknown',
#   'other',
#   'white',
#   '2013 Ford F-350 F350 F 350 SD XLT Crew Cab Long Bed 4WD -- INTERNET SALE PRICE ENDS SATURDAY APRIL 17TH     Offered by: R21 Motorsports — (330) 281-4072 — $29,995     In an effort to provide the best response time possible to our Facebook Marketplace customers we are asking that you temporarily discontinue use of the automated "Is This Still Available" tab on marketplace.  Our inventory feed updates several times throughout the day.  This will help our team to better assist you with your sales, selection and technical questions.  6.2L V8 GAS ENGINE, 4 WHEEL DRIVE, LONG BED, RUNNING BOARDS, TOW PACKAGE, FX4 PACKAGE, BLUETOOTH,...ASK ABOUT OUR TRUCK FINANCING PROGRAM & NATIONWIDE TRUCK EXTENDED SERVICE CONTRACTS ....IF R21 MOTORSPORTS HAS THE OPPORTUNITY TO HELP YOU IN THESE DIFFICULT TIMES ...WE WILL DO OUR BEST TO PROVIDE YOU FAIR, HONEST AND STRAIGHT FORWARD TRANSACTION ....LOOK FORWARD TO HEARING FROM YOU AND PLEASE TAKE CARE....REDUCED FROM $30,995 FOR IMMEDIATE SALE...   R21 Motorsports    Year: 2013 Make: Ford Model: F-350 SD Series: XLT Crew Cab Long Bed 4WD -- INTERNET SALE PRICE ENDS SATURDAY APRIL 17TH VIN: 1FT8W3B65DEA06194 Stock #: 18910 Condition: Used Mileage: 85,450  Exterior: WHITE Interior: GRAY Body: CREW CAB PICKUP 4-DR Transmission: 6-Speed Automatic Engine: 6.2L V8 OHV 16V      We have Financing for everyone and over 100 trucks and vehicles to choose from here at R21 Motorsports!  Call us at 330-281-4072, or text us 24/7!!       More vehicle details: r21-motorsports.hammerwebsites.net/v/GZaWLGti     Address: 5315 Butterbridge Rd NW Canal Fulton, OH 44614   Phone: (330) 281-4072     Website: www.r21motorsports.com/      📲 ☎️ Call or text (330) 281-4072 for quick answers to your questions about this Ford F-350 SD Your message will always be answered by a real human — never an automated system.     Disclaimer: R21 Motorsports will never sell, share, or spam your mobile number. Standard text messaging rates may apply. Vehicles are described to the best of our abilities, please call to verify information, pricing, and availability.      2013 Ford F-350 SD XLT Crew Cab Long Bed 4WD -- INTERNET SALE PRICE ENDS SATURDAY APRIL 17TH   e855683af07146bda483e6f8f2fcfbf0',
#   'Unknown',
#   'oh',
#   Timestamp('2021-05-01 00:00:00+0000', tz='UTC')),
#  (286533,
#   7315398048,
#   'akron / canton',
#   24995.0,
#   2013,
#   'ram',
#   '1500',
#   'Unknown',
#   'Unknown',
#   'gas',
#   79831,
#   'clean',
#   'automatic',
#   'Unknown',
#   'Unknown',
#   'other',
#   'white',
#   '2013 RAM 1500 Laramie Crew Cab LWB 4WD -- INTERNET SALE PRICE ENDS SATURDAY APRIL 17TH     Offered by: R21 Motorsports — (330) 281-4072 — $24,995     In an effort to provide the best response time possible to our Facebook Marketplace customers we are asking that you temporarily discontinue use of the automated "Is This Still Available" tab on marketplace.  Our inventory feed updates several times throughout the day.  This will help our team to better assist you with your sales, selection and technical questions.  5.7L V8 HEMI ENGINE, 4X4, LONG BED, ALLOY WHELS, RUNNING BOARDS, TOW PACKAGE, NAVIGATION SYSTEM, LEATHER SEATS, HEATED SEATS, POWER SEATS, BLUETOOTH, AND MUCH MORE. CALL US TODAY AT 330-854-5380.....ASK ABOUT OUR TRUCK FINANCING PROGRAM & NATIONWIDE TRUCK EXTENDED SERVICE CONTRACTS ....IF R21 MOTORSPORTS HAS THE OPPORTUNITY TO HELP YOU IN THESE DIFFICULT TIMES ...WE WILL DO OUR BEST TO PROVIDE YOU FAIR, HONEST AND STRAIGHT FORWARD TRANSACTION ....LOOK FORWARD TO HEARING FROM YOU AND PLEASE TAKE CARE...REDUCED FROM $25,995....MUST TAKE DELIVERY ON OR BEFORE APRIL 17TH TO RECIEVE SPECIAL SALE PRICING...   R21 Motorsports    Year: 2013 Make: RAM Model: 1500 Series: Laramie Crew Cab LWB 4WD -- INTERNET SALE PRICE ENDS SATURDAY APRIL 17TH VIN: 1C6RR7VT8DS675833 Stock #: 18894 Condition: Used Mileage: 79,831  Exterior: WHITE Interior: GRAY Body: CREW CAB PICKUP 4-DR Transmission: 6-Speed Automatic Engine: 5.7L V8 OHV 16V      We have Financing for everyone and over 100 trucks and vehicles to choose from here at R21 Motorsports!  Call us at 330-281-4072, or text us 24/7!!       More vehicle details: r21-motorsports.hammerwebsites.net/v/tD6zQUnJ     Address: 5315 Butterbridge Rd NW Canal Fulton, OH 44614   Phone: (330) 281-4072     Website: www.r21motorsports.com/      📲 ☎️ Call or text (330) 281-4072 for quick answers to your questions about this RAM 1500 Your message will always be answered by a real human — never an automated system.     Disclaimer: R21 Motorsports will never sell, share, or spam your mobile number. Standard text messaging rates may apply. Vehicles are described to the best of our abilities, please call to verify information, pricing, and availability.      2013 RAM 1500 Laramie Crew Cab LWB 4WD -- INTERNET SALE PRICE ENDS SATURDAY APRIL 17TH   fe10272ff6ec4c2ab8a438f4257cce55',
#   'Unknown',
#   'oh',
#   Timestamp('2021-05-01 00:00:00+0000', tz='UTC')),
#  (288035,
#   7304642048,
#   'akron / canton',
#   26995.0,
#   2013,
#   'ram',
#   '1500',
#   'Unknown',
#   'Unknown',
#   'gas',
#   88578,
#   'clean',
#   'automatic',
#   'Unknown',
#   'Unknown',
#   'other',
#   'white',
#   '2013 RAM 1500 Sport Quad Cab 4WD     Offered by: R21 Motorsports — (330) 281-4072 — $26,995     In an effort to provide the best response time possible to our Facebook Marketplace customers we are asking that you temporarily discontinue use of the automated "Is This Still Available" tab on marketplace.  Our inventory feed updates several times throughout the day.  This will help our team to better assist you with your sales, selection and technical questions.  5.7L V8 HEMI ENGINE, 4 WHEEL DRIVE, ALLOY WHEELS,  BED COVER, TOW PACKAGE, BLUETOOTH, TOUCH SCREEN, ONLY 88K MILES!!  CALL US AT 330-854-5380   R21 Motorsports    Year: 2013 Make: RAM Model: 1500 Series: Sport Quad Cab 4WD VIN: 1C6RR7HT9DS551551 Stock #: 18956 Condition: Used Mileage: 88,578  Exterior: WHITE Interior: BLACK Body: CREW CAB PICKUP 4-DR Transmission: 6-Speed Automatic Engine: 5.7L V8 OHV 16V      We have Financing for everyone and over 100 trucks and vehicles to choose from here at R21 Motorsports!  Call us at 330-281-4072, or text us 24/7!!       More vehicle details: r21-motorsports.hammerwebsites.net/v/N9ItRSvY     Address: 5315 Butterbridge Rd NW Canal Fulton, OH 44614   Phone: (330) 281-4072     Website: www.r21motorsports.com/      📲 ☎️ Call or text (330) 281-4072 for quick answers to your questions about this RAM 1500 Your message will always be answered by a real human — never an automated system.     Disclaimer: R21 Motorsports will never sell, share, or spam your mobile number. Standard text messaging rates may apply. Vehicles are described to the best of our abilities, please call to verify information, pricing, and availability.      2013 RAM 1500 Sport Quad Cab 4WD   d82ad27cad4642fb9e487ec8a488297f',
#   'Unknown',
#   'oh',
#   Timestamp('2021-04-10 00:00:00+0000', tz='UTC')),
#  ...]

# %% [markdown]
# <b>Save the list as a txt file</b>

# %%
file= open('vehicles_craiglist.txt','w')
for tuple in col:
    file.write(str(tuple)+ ','+ '\n')
    
file.close()

# %%
import os

# Get the current working directory
current_directory = os.getcwd()

# Construct the full path to the "vehicles.txt" file
file_path = os.path.join(current_directory, 'vehicles_craiglist.txt')

print(f"The 'vehicles_craiglist.txt' file is located at: {file_path}")
# Out:
# The 'vehicles_craiglist.txt' file is located at: /kaggle/working/vehicles_craiglist.txt
